# %%
import pandas as pd

df = pd.read_excel("excel_ark/GK_Spjeld.xlsx")
df2 = pd.read_excel("excel_ark/Spjeldliste CAV ved Qbrann Bygg 11, 21, 22, 23.xlsx")

# %%
print(df2.head())
# Out:
#                               Description                              Tag  \
# 0  CAV-spjeld for generell luftbehandling  +215021=360.302:01-SKZ.006T/010
# 1  CAV-spjeld for generell luftbehandling  +215021=360.302:01-SKZ.006T/052
# 2  CAV-spjeld for generell luftbehandling  +215021=360.302:01-SKZ.007T/014
# 3  CAV-spjeld for generell luftbehandling  +215021=360.302:01-SKZ.007T/015
# 4  CAV-spjeld for generell luftbehandling  +215021=360.302:01-SKZ.007T/988
#
#    Qmax  Qmin  Qbrann  Qnom  % av nominell  Unnamed: 7
# 0   600   600   240.0  1080       0.222222         NaN
# 1   600   600   240.0  1080       0.222222         NaN
# 2   300   300   120.0   684       0.175439         NaN
# 3   300   300   120.0   684       0.175439         NaN
# 4   300   300   120.0   684       0.175439         NaN
