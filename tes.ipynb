# %%
import pandas as pd

df = pd.read_excel("excel_ark/CAV_og_VAV/360.503.xlsx")
df2 = pd.read_excel("excel_ark/Spjeldliste CAV ved Qbrann Bygg 11, 21, 22, 23.xlsx")

# %%
print(df.head())

for i in range(len(df["Qnom"])):
    print(type(df["Qnom"][i]))
# Out:
#                         Description                               Tag  Qmax  \
# 0  CAV-Spjeld Generel Luftfordeling  +215011=360.503:01-SKZ.004T/1353   850
# 1  CAV-Spjeld Generel Luftfordeling  +215011=360.503:01-SKZ.004T/1411  1200
# 2  CAV-Spjeld Generel Luftfordeling  +215011=360.503:01-SKZ.004T/2485  1360
# 3  CAV-Spjeld Generel Luftfordeling   +215011=360.503:01-SKZ.004T/897  1000
# 4  CAV-Spjeld Generel Luftfordeling   +215011=360.503:01-SKZ.004T/899  1385
#
#    Qmin    Qnom  Qmax % av Qnom  Qmin % av Qnom  \
# 0   850  1750.0        0.485714        0.485714
# 1  1200  1750.0        0.685714        0.685714
# 2  1360  1750.0        0.777143        0.777143
# 3  1000  1750.0        0.571429        0.571429
# 4  1385  1750.0        0.791429        0.791429
#
#    Påadrag ved tilstedeværelse [%]  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# ...
